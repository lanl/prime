# %% [markdown]
# # RBD ADO Cluster Plot Comparison
#
# Comparing the clusters for the RBD (Alpha, Delta, Omicron) graph.
#
# ---
# ### Alpha (Cluster 2)

# %%
import pandas as pd

# ESM-RBD Embedded
seed = 0
perplexity = 750
csv_file = f"rbd_ado/RBD.ADO.from-esm-mlm.CLS-embedded.sampled_seed0.tSNE-perplexity750.cluster2.csv"
esm_rbd_df = pd.read_csv(csv_file)
print(esm_rbd_df["Variant"].value_counts())

# ESM Embedded
seed = 0
perplexity = 1000
csv_file = f"rbd_ado/RBD.ADO.CLS-embedded.sampled_seed{seed}.tSNE-perplexity{perplexity}.cluster2.csv"
esm_df = pd.read_csv(csv_file)
print(esm_df["Variant"].value_counts())

# MSA + One-Hot Embedded
seed = 0
perplexity = 1000
csv_file = f"rbd_ado_msa/RBD.ADO.MSA.tSNE-perplexity{perplexity}.cluster2.csv"
msa_df = pd.read_csv(csv_file)
print(msa_df["Variant"].value_counts())
# Out:
# Variant
# Alpha      21974
# Omicron      218
# Delta         93
# Name: count, dtype: int64
# Variant
# Alpha      21980
# Omicron      308
# Delta        283
# Name: count, dtype: int64
# Variant
# Alpha      21997
# Omicron      427
# Delta         93
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib_venn import venn3
from matplotlib_venn.layout.venn3 import DefaultLayoutAlgorithm
from matplotlib.patches import Patch

def plot_venn3(sets, sequences_variant, majority_variant, colors):
    sns.set_style('ticks')
    sns.set_context("talk")
    plt.figure(figsize=(8, 4.5))
    # colors = ["tab:blue", "tab:orange", "tab:green"]

    plt.title(f"Overlap of {sequences_variant} Sequences in Majority {majority_variant} Cluster")
    venn = venn3(
        layout_algorithm=DefaultLayoutAlgorithm(fixed_subset_sizes=(1, 1, 1, 1, 1, 1, 1)), # unweighted
        subsets=sets, 
        set_labels=('ESM-RBD', 'ESM', 'MSA'),
        set_colors=colors,
        alpha=0.8
    )

    # Outline each circle
    for circle in venn.patches:
        if circle:
            circle.set_edgecolor('black')  # Outline color
            circle.set_linewidth(1.5)        # Outline width (adjust as desired)

    # # Set the set label colors
    # for i, text in enumerate(venn.set_labels):
    #     text.set_color(colors[i])

    # Make the numbers in the diagram bold
    for subset_label in venn.subset_labels:
        if subset_label: 
            subset_label.set_fontweight('bold')
            subset_label.set_color('k')

    save_as = f"venn_diagrams/{sequences_variant}_seqs_within_{majority_variant}_cluster.venn"
    plt.savefig(f"{save_as}.pdf", format="pdf", dpi=300, bbox_inches='tight')
    plt.show()

# %%
esm_rbd_alpha_df = esm_rbd_df[esm_rbd_df["Variant"] == "Alpha"]
esm_alpha_df = esm_df[esm_df["Variant"] == "Alpha"]
msa_alpha_df = msa_df[msa_df["Variant"] == "Alpha"]

# Convert columns to sets
set1 = set(esm_rbd_alpha_df["Seq ID"])
set2 = set(esm_alpha_df["Seq ID"])
set3 = set(msa_alpha_df["Seq ID"])

# Find differences
only_in_set1 = set1 - set2 - set3
only_in_set2 = set2 - set1 - set3
only_in_set3 = set3 - set1 - set2

print(f"Ground truth Alpha only in ESM RBD majority Alpha cluster ({len(only_in_set1)} seq(s)):\n{only_in_set1}")
print(f"Ground truth Alpha only in ESM majority Alpha cluster ({len(only_in_set2)} seq(s)):\n{only_in_set2}")
print(f"Ground truth Alpha only in MSA majority Alpha cluster ({len(only_in_set3)} seq(s)):\n{only_in_set3}")

plot_venn3([set1, set2, set3], "Alpha", "Alpha", colors = ["#00010DFF", "tab:blue", "#93ABBFFF"])
# Out:
# Ground truth Alpha only in ESM RBD majority Alpha cluster (0 seq(s)):
# set()
# Ground truth Alpha only in ESM majority Alpha cluster (10 seq(s)):
# {'EPI_ISL_1627570', 'EPI_ISL_11036528', 'EPI_ISL_3497312', 'EPI_ISL_3058159', 'EPI_ISL_11036678', 'EPI_ISL_2673783', 'EPI_ISL_1798651', 'EPI_ISL_1802084', 'EPI_ISL_3091093', 'EPI_ISL_1098250'}
# Ground truth Alpha only in MSA majority Alpha cluster (1 seq(s)):
# {'EPI_ISL_3948597'}

# %%
esm_rbd_delta_df = esm_rbd_df[esm_rbd_df["Variant"] == "Delta"]
esm_delta_df = esm_df[esm_df["Variant"] == "Delta"]
msa_delta_df = msa_df[msa_df["Variant"] == "Delta"]

# Convert columns to sets
set1 = set(esm_rbd_delta_df["Seq ID"])
set2 = set(esm_delta_df["Seq ID"])
set3 = set(msa_delta_df["Seq ID"])

# Find differences
only_in_set1 = set1 - set2 - set3
only_in_set2 = set2 - set1 - set3
only_in_set3 = set3 - set1 - set2

print(f"Ground truth Delta only in ESM RBD majority Alpha cluster ({len(only_in_set1)} seq(s)):\n{only_in_set1}")
print(f"Ground truth Delta only in ESM majority Alpha cluster ({len(only_in_set2)} seq(s):\n{only_in_set2}")
print(f"Ground truth Delta only in MSA majority Alpha cluster (({len(only_in_set3)} seq(s)):\n{only_in_set3}")

plot_venn3([set1, set2, set3], "Delta", "Alpha", colors = ["#00010DFF", "tab:blue", "#93ABBFFF"])
# Out:
# Ground truth Delta only in ESM RBD majority Alpha cluster (1 seq(s)):
# {'EPI_ISL_3063359'}
# Ground truth Delta only in ESM majority Alpha cluster (192 seq(s):
# {'EPI_ISL_6695445', 'EPI_ISL_11580749', 'EPI_ISL_4913525', 'EPI_ISL_9201789', 'EPI_ISL_9610701', 'EPI_ISL_7923176', 'EPI_ISL_7970489', 'EPI_ISL_2957030', 'EPI_ISL_3946276', 'EPI_ISL_3667363', 'EPI_ISL_10716776', 'EPI_ISL_4029497', 'EPI_ISL_5866932', 'EPI_ISL_5372488', 'EPI_ISL_7566108', 'EPI_ISL_7970701', 'EPI_ISL_4949769', 'EPI_ISL_6651953', 'EPI_ISL_8604038', 'EPI_ISL_8082701', 'EPI_ISL_10093300', 'EPI_ISL_3907113', 'EPI_ISL_6161119', 'EPI_ISL_7425392', 'EPI_ISL_4997289', 'EPI_ISL_12906203', 'EPI_ISL_3533179', 'EPI_ISL_4983426', 'EPI_ISL_9677239', 'EPI_ISL_3833521', 'EPI_ISL_9324200', 'EPI_ISL_9345273', 'EPI_ISL_7232252', 'EPI_ISL_8000358', 'EPI_ISL_7133346', 'EPI_ISL_6171694', 'EPI_ISL_6161601', 'EPI_ISL_3856457', 'EPI_ISL_4540026', 'EPI_ISL_6573091', 'EPI_ISL_2828170', 'EPI_ISL_4910349', 'EPI_ISL_6561870', 'EPI_ISL_10096547', 'EPI_ISL_6631200', 'EPI_ISL_8486319', 'EPI_ISL_6701364', 'EPI_ISL_4911036', 'EPI_ISL_6204977', 'EPI_ISL_7424824', 'EPI_ISL_8082583', 'EPI_ISL_4400619', 'EPI_ISL_7366338', 'EPI_ISL_3403619', 'EPI_ISL_8136309', 'EPI_ISL_8515072', 'EPI_ISL_6550623', 'EPI_ISL_2988040', 'EPI_ISL_8603962', 'EPI_ISL_5641253', 'EPI_ISL_4301857', 'EPI_ISL_2962468', 'EPI_ISL_6688452', 'EPI_ISL_6785048', 'EPI_ISL_8221869', 'EPI_ISL_9103207', 'EPI_ISL_4498136', 'EPI_ISL_6170401', 'EPI_ISL_9324893', 'EPI_ISL_7943724', 'EPI_ISL_8077772', 'EPI_ISL_11685361', 'EPI_ISL_6545531', 'EPI_ISL_6536721', 'EPI_ISL_6694019', 'EPI_ISL_5003810', 'EPI_ISL_8082674', 'EPI_ISL_5549836', 'EPI_ISL_6693891', 'EPI_ISL_16608015', 'EPI_ISL_8066664', 'EPI_ISL_7920489', 'EPI_ISL_3691277', 'EPI_ISL_5030205', 'EPI_ISL_4949842', 'EPI_ISL_3833516', 'EPI_ISL_8082744', 'EPI_ISL_16799659', 'EPI_ISL_6485362', 'EPI_ISL_11856441', 'EPI_ISL_4054973', 'EPI_ISL_5641327', 'EPI_ISL_7366353', 'EPI_ISL_6559259', 'EPI_ISL_7424461', 'EPI_ISL_2984527', 'EPI_ISL_8082637', 'EPI_ISL_6693963', 'EPI_ISL_9345271', 'EPI_ISL_5991421', 'EPI_ISL_7970750', 'EPI_ISL_3541269', 'EPI_ISL_12906201', 'EPI_ISL_6515457', 'EPI_ISL_6163749', 'EPI_ISL_9345307', 'EPI_ISL_7970811', 'EPI_ISL_8082649', 'EPI_ISL_7565864', 'EPI_ISL_8082783', 'EPI_ISL_6693853', 'EPI_ISL_12906206', 'EPI_ISL_6571558', 'EPI_ISL_6693898', 'EPI_ISL_6693943', 'EPI_ISL_4949749', 'EPI_ISL_5581017', 'EPI_ISL_6421475', 'EPI_ISL_17675888', 'EPI_ISL_3656681', 'EPI_ISL_7568482', 'EPI_ISL_8082750', 'EPI_ISL_3010471', 'EPI_ISL_7970513', 'EPI_ISL_4057257', 'EPI_ISL_5113041', 'EPI_ISL_5518019', 'EPI_ISL_7970560', 'EPI_ISL_11268213', 'EPI_ISL_8425971', 'EPI_ISL_9524269', 'EPI_ISL_6541002', 'EPI_ISL_3230558', 'EPI_ISL_7900020', 'EPI_ISL_7970737', 'EPI_ISL_8714861', 'EPI_ISL_7566054', 'EPI_ISL_8082801', 'EPI_ISL_8603975', 'EPI_ISL_7424778', 'EPI_ISL_7424112', 'EPI_ISL_6571435', 'EPI_ISL_8356800', 'EPI_ISL_3857699', 'EPI_ISL_7245864', 'EPI_ISL_3533184', 'EPI_ISL_7232752', 'EPI_ISL_5641188', 'EPI_ISL_6010220', 'EPI_ISL_6631336', 'EPI_ISL_9702426', 'EPI_ISL_9132577', 'EPI_ISL_5641317', 'EPI_ISL_6701383', 'EPI_ISL_7424288', 'EPI_ISL_3432357', 'EPI_ISL_5641865', 'EPI_ISL_6629487', 'EPI_ISL_4875665', 'EPI_ISL_10714873', 'EPI_ISL_6171218', 'EPI_ISL_5641173', 'EPI_ISL_9677230', 'EPI_ISL_3849546', 'EPI_ISL_6571358', 'EPI_ISL_7970583', 'EPI_ISL_7970520', 'EPI_ISL_5370460', 'EPI_ISL_3540396', 'EPI_ISL_3230491', 'EPI_ISL_6572519', 'EPI_ISL_7405755', 'EPI_ISL_6170051', 'EPI_ISL_3236135', 'EPI_ISL_16109885', 'EPI_ISL_3833500', 'EPI_ISL_8082650', 'EPI_ISL_8727839', 'EPI_ISL_2787132', 'EPI_ISL_5427483', 'EPI_ISL_12569666', 'EPI_ISL_3399891', 'EPI_ISL_9201696', 'EPI_ISL_6629633', 'EPI_ISL_6514392', 'EPI_ISL_6541443', 'EPI_ISL_3533188', 'EPI_ISL_4381911', 'EPI_ISL_7779573', 'EPI_ISL_4141134', 'EPI_ISL_5371942', 'EPI_ISL_2958832'}
# Ground truth Delta only in MSA majority Alpha cluster ((0 seq(s)):
# set()

# %%
esm_rbd_omicron_df = esm_rbd_df[esm_rbd_df["Variant"] == "Omicron"]
esm_omicron_df = esm_df[esm_df["Variant"] == "Omicron"]
msa_omicron_df = msa_df[msa_df["Variant"] == "Omicron"]

# Convert columns to sets
set1 = set(esm_rbd_omicron_df["Seq ID"])
set2 = set(esm_omicron_df["Seq ID"])
set3 = set(msa_omicron_df["Seq ID"])

# Find differences
only_in_set1 = set1 - set2 - set3
only_in_set2 = set2 - set1 - set3
only_in_set3 = set3 - set1 - set2

print(f"Ground truth Omicron only in ESM RBD majority Alpha cluster ({len(only_in_set1)} seq(s)):\n{only_in_set1}")
print(f"Ground truth Omicron only in ESM majority Alpha cluster ({len(only_in_set2)} seq(s):\n{only_in_set2}")
print(f"Ground truth Omicron only in MSA majority Alpha cluster (({len(only_in_set3)} seq(s)):\n{only_in_set3}")

#00010DFF, #032CA6FF, #034AA6FF, #035AA6FF, #93ABBFFF
plot_venn3([set1, set2, set3], "Omicron", "Alpha", colors = ["#00010DFF", "tab:blue", "#93ABBFFF"])
# Out:
# Ground truth Omicron only in ESM RBD majority Alpha cluster (39 seq(s)):
# {'EPI_ISL_11084124', 'EPI_ISL_13295446', 'EPI_ISL_17214253', 'EPI_ISL_11931066', 'EPI_ISL_12133818', 'EPI_ISL_12704498', 'EPI_ISL_8513971', 'EPI_ISL_9227490', 'EPI_ISL_8518693', 'EPI_ISL_8746647', 'EPI_ISL_14561381', 'EPI_ISL_9582395', 'EPI_ISL_9202411', 'EPI_ISL_9417029', 'EPI_ISL_8284507', 'EPI_ISL_13762293', 'EPI_ISL_8336438', 'EPI_ISL_10088223', 'EPI_ISL_9631959', 'EPI_ISL_8336454', 'EPI_ISL_11948879', 'EPI_ISL_14721894', 'EPI_ISL_8336441', 'EPI_ISL_11905472', 'EPI_ISL_12749913', 'EPI_ISL_14952220', 'EPI_ISL_14722976', 'EPI_ISL_11344916', 'EPI_ISL_9227748', 'EPI_ISL_14722985', 'EPI_ISL_15582076', 'EPI_ISL_10114898', 'EPI_ISL_12272394', 'EPI_ISL_9202992', 'EPI_ISL_14722968', 'EPI_ISL_11630165', 'EPI_ISL_12803966', 'EPI_ISL_13073691', 'EPI_ISL_9512430'}
# Ground truth Omicron only in ESM majority Alpha cluster (22 seq(s):
# {'EPI_ISL_14429412', 'EPI_ISL_16252692', 'EPI_ISL_16763203', 'EPI_ISL_17104011', 'EPI_ISL_17196729', 'EPI_ISL_16674995', 'EPI_ISL_16104801', 'EPI_ISL_14973044', 'EPI_ISL_10103967', 'EPI_ISL_17068265', 'EPI_ISL_8801343', 'EPI_ISL_17601398', 'EPI_ISL_16400518', 'EPI_ISL_16886595', 'EPI_ISL_9366739', 'EPI_ISL_8402522', 'EPI_ISL_16066642', 'EPI_ISL_14008900', 'EPI_ISL_17104086', 'EPI_ISL_14582373', 'EPI_ISL_15617549', 'EPI_ISL_9787001'}
# Ground truth Omicron only in MSA majority Alpha cluster ((193 seq(s)):
# {'EPI_ISL_16252411', 'EPI_ISL_11404263', 'EPI_ISL_15144670', 'EPI_ISL_14008458', 'EPI_ISL_12804133', 'EPI_ISL_16495425', 'EPI_ISL_10104938', 'EPI_ISL_8335190', 'EPI_ISL_8471253', 'EPI_ISL_15250700', 'EPI_ISL_15805759', 'EPI_ISL_10066028', 'EPI_ISL_8524611', 'EPI_ISL_8751515', 'EPI_ISL_14006145', 'EPI_ISL_15870394', 'EPI_ISL_12830492', 'EPI_ISL_13845183', 'EPI_ISL_8259683', 'EPI_ISL_13295404', 'EPI_ISL_16134927', 'EPI_ISL_10213448', 'EPI_ISL_16252408', 'EPI_ISL_8077941', 'EPI_ISL_9045447', 'EPI_ISL_8502013', 'EPI_ISL_14582916', 'EPI_ISL_10832788', 'EPI_ISL_15782410', 'EPI_ISL_15805615', 'EPI_ISL_14582868', 'EPI_ISL_14854940', 'EPI_ISL_15783315', 'EPI_ISL_15248350', 'EPI_ISL_17068262', 'EPI_ISL_10869501', 'EPI_ISL_15142893', 'EPI_ISL_9338672', 'EPI_ISL_17001717', 'EPI_ISL_11685260', 'EPI_ISL_8357012', 'EPI_ISL_13388912', 'EPI_ISL_12061107', 'EPI_ISL_14356994', 'EPI_ISL_8470816', 'EPI_ISL_14857616', 'EPI_ISL_14087769', 'EPI_ISL_11478963', 'EPI_ISL_17275841', 'EPI_ISL_15805755', 'EPI_ISL_10298465', 'EPI_ISL_9630050', 'EPI_ISL_13395634', 'EPI_ISL_13900147', 'EPI_ISL_15782464', 'EPI_ISL_15144658', 'EPI_ISL_16066656', 'EPI_ISL_13395546', 'EPI_ISL_14973153', 'EPI_ISL_13341597', 'EPI_ISL_15356376', 'EPI_ISL_15805729', 'EPI_ISL_10214694', 'EPI_ISL_15805659', 'EPI_ISL_15782501', 'EPI_ISL_14854964', 'EPI_ISL_15949555', 'EPI_ISL_14251975', 'EPI_ISL_12569900', 'EPI_ISL_14335259', 'EPI_ISL_9073739', 'EPI_ISL_12127165', 'EPI_ISL_9076583', 'EPI_ISL_10072782', 'EPI_ISL_14245179', 'EPI_ISL_10066020', 'EPI_ISL_10016789', 'EPI_ISL_8524465', 'EPI_ISL_9258951', 'EPI_ISL_8870550', 'EPI_ISL_15870466', 'EPI_ISL_14083080', 'EPI_ISL_13660469', 'EPI_ISL_13295267', 'EPI_ISL_10213136', 'EPI_ISL_9526786', 'EPI_ISL_14583212', 'EPI_ISL_15797225', 'EPI_ISL_11621345', 'EPI_ISL_16701385', 'EPI_ISL_14854879', 'EPI_ISL_15262672', 'EPI_ISL_14245359', 'EPI_ISL_8871840', 'EPI_ISL_13762446', 'EPI_ISL_10220456', 'EPI_ISL_13492755', 'EPI_ISL_10093082', 'EPI_ISL_10189711', 'EPI_ISL_14971063', 'EPI_ISL_8814959', 'EPI_ISL_10072777', 'EPI_ISL_15782558', 'EPI_ISL_9139377', 'EPI_ISL_9679005', 'EPI_ISL_10547320', 'EPI_ISL_16752525', 'EPI_ISL_15797038', 'EPI_ISL_14008954', 'EPI_ISL_9629825', 'EPI_ISL_17001728', 'EPI_ISL_17068341', 'EPI_ISL_8551553', 'EPI_ISL_14083316', 'EPI_ISL_13167063', 'EPI_ISL_13295372', 'EPI_ISL_14357053', 'EPI_ISL_8524626', 'EPI_ISL_14971035', 'EPI_ISL_8606235', 'EPI_ISL_9803389', 'EPI_ISL_10721648', 'EPI_ISL_13845342', 'EPI_ISL_15144661', 'EPI_ISL_8606219', 'EPI_ISL_8524430', 'EPI_ISL_8259621', 'EPI_ISL_8606253', 'EPI_ISL_8686723', 'EPI_ISL_10545047', 'EPI_ISL_13762563', 'EPI_ISL_14083101', 'EPI_ISL_14356903', 'EPI_ISL_8335442', 'EPI_ISL_13272942', 'EPI_ISL_10229569', 'EPI_ISL_9151643', 'EPI_ISL_14582830', 'EPI_ISL_14245291', 'EPI_ISL_17104050', 'EPI_ISL_8551461', 'EPI_ISL_13900066', 'EPI_ISL_16252722', 'EPI_ISL_8524581', 'EPI_ISL_8501972', 'EPI_ISL_13295402', 'EPI_ISL_11531501', 'EPI_ISL_8606227', 'EPI_ISL_8308594', 'EPI_ISL_8357004', 'EPI_ISL_12567816', 'EPI_ISL_13295411', 'EPI_ISL_14854874', 'EPI_ISL_12567854', 'EPI_ISL_9201846', 'EPI_ISL_16643994', 'EPI_ISL_8606245', 'EPI_ISL_11260034', 'EPI_ISL_10093094', 'EPI_ISL_17001745', 'EPI_ISL_14245295', 'EPI_ISL_14583021', 'EPI_ISL_9021878', 'EPI_ISL_10302375', 'EPI_ISL_14970999', 'EPI_ISL_8265828', 'EPI_ISL_14007485', 'EPI_ISL_14357050', 'EPI_ISL_11261646', 'EPI_ISL_9526744', 'EPI_ISL_13762511', 'EPI_ISL_17104054', 'EPI_ISL_14245321', 'EPI_ISL_9516065', 'EPI_ISL_8815575', 'EPI_ISL_9633835', 'EPI_ISL_10082837', 'EPI_ISL_8953235', 'EPI_ISL_16252744', 'EPI_ISL_11493647', 'EPI_ISL_15805722', 'EPI_ISL_12882261', 'EPI_ISL_11261916', 'EPI_ISL_13295272', 'EPI_ISL_8753323', 'EPI_ISL_8544470', 'EPI_ISL_15253856', 'EPI_ISL_15797192', 'EPI_ISL_14971586', 'EPI_ISL_14008988', 'EPI_ISL_15797141', 'EPI_ISL_11404207', 'EPI_ISL_13286452'}

# %% [markdown]
# ---
# ### Delta (Cluster 0)

# %%
import pandas as pd

# ESM-RBD Embedded
seed = 0
perplexity = 750
csv_file = f"rbd_ado/RBD.ADO.from-esm-mlm.CLS-embedded.sampled_seed0.tSNE-perplexity750.cluster0.csv"
esm_rbd_df = pd.read_csv(csv_file)
print(esm_rbd_df["Variant"].value_counts())

# ESM Embedded
seed = 0
perplexity = 1000
csv_file = f"rbd_ado/RBD.ADO.CLS-embedded.sampled_seed{seed}.tSNE-perplexity{perplexity}.cluster0.csv"
esm_df = pd.read_csv(csv_file)
print(esm_df["Variant"].value_counts())

# MSA + One-Hot Embedded
seed = 0
perplexity = 1000
csv_file = f"rbd_ado_msa/RBD.ADO.MSA.tSNE-perplexity{perplexity}.cluster0.csv"
msa_df = pd.read_csv(csv_file)
print(msa_df["Variant"].value_counts())
# Out:
# Variant
# Delta      21958
# Alpha         79
# Omicron       70
# Name: count, dtype: int64
# Variant
# Delta      21786
# Alpha         95
# Omicron       76
# Name: count, dtype: int64
# Variant
# Delta      21982
# Omicron      103
# Alpha         78
# Name: count, dtype: int64

# %%
esm_rbd_alpha_df = esm_rbd_df[esm_rbd_df["Variant"] == "Alpha"]
esm_alpha_df = esm_df[esm_df["Variant"] == "Alpha"]
msa_alpha_df = msa_df[msa_df["Variant"] == "Alpha"]

# Convert columns to sets
set1 = set(esm_rbd_alpha_df["Seq ID"])
set2 = set(esm_alpha_df["Seq ID"])
set3 = set(msa_alpha_df["Seq ID"])

# Find differences
only_in_set1 = set1 - set2 - set3
only_in_set2 = set2 - set1 - set3
only_in_set3 = set3 - set1 - set2

print(f"Ground truth Alpha only in ESM RBD majority Delta cluster ({len(only_in_set1)} seq(s)):\n{only_in_set1}")
print(f"Ground truth Alpha only in ESM majority Delta cluster ({len(only_in_set2)} seq(s)):\n{only_in_set2}")
print(f"Ground truth Alpha only in MSA majority Delta cluster ({len(only_in_set3)} seq(s)):\n{only_in_set3}")

#F1CFA2FF, #F8BC64FF, #E68B47FF, #BD6E39FF, #4A2C22FF
plot_venn3([set1, set2, set3], "Alpha", "Delta", colors = ["#4A2C22FF", "tab:orange", "#F1CFA2FF"])
# Out:
# Ground truth Alpha only in ESM RBD majority Delta cluster (0 seq(s)):
# set()
# Ground truth Alpha only in ESM majority Delta cluster (26 seq(s)):
# {'EPI_ISL_2235772', 'EPI_ISL_2981362', 'EPI_ISL_1838736', 'EPI_ISL_1257407', 'EPI_ISL_2400403', 'EPI_ISL_3717315', 'EPI_ISL_2022602', 'EPI_ISL_2315171', 'EPI_ISL_1741658', 'EPI_ISL_2445952', 'EPI_ISL_3391045', 'EPI_ISL_12425719', 'EPI_ISL_2933265', 'EPI_ISL_9949793', 'EPI_ISL_1616379', 'EPI_ISL_1389628', 'EPI_ISL_4372991', 'EPI_ISL_1741577', 'EPI_ISL_1647662', 'EPI_ISL_4505536', 'EPI_ISL_5337157', 'EPI_ISL_2002889', 'EPI_ISL_2862440', 'EPI_ISL_1528242', 'EPI_ISL_3155006', 'EPI_ISL_2487615'}
# Ground truth Alpha only in MSA majority Delta cluster (0 seq(s)):
# set()

# %%
esm_rbd_delta_df = esm_rbd_df[esm_rbd_df["Variant"] == "Delta"]
esm_delta_df = esm_df[esm_df["Variant"] == "Delta"]
msa_delta_df = msa_df[msa_df["Variant"] == "Delta"]

# Convert columns to sets
set1 = set(esm_rbd_delta_df["Seq ID"])
set2 = set(esm_delta_df["Seq ID"])
set3 = set(msa_delta_df["Seq ID"])

# Find differences
only_in_set1 = set1 - set2 - set3
only_in_set2 = set2 - set1 - set3
only_in_set3 = set3 - set1 - set2

print(f"Ground truth Delta only in ESM RBD majority Delta cluster ({len(only_in_set1)} seq(s)):\n{only_in_set1}")
print(f"Ground truth Delta only in ESM majority Delta cluster ({len(only_in_set2)} seq(s):\n{only_in_set2}")
print(f"Ground truth Delta only in MSA majority Delta cluster (({len(only_in_set3)} seq(s)):\n{only_in_set3}")

plot_venn3([set1, set2, set3], "Delta", "Delta", colors = ["#4A2C22FF", "tab:orange", "#F1CFA2FF"])
# Out:
# Ground truth Delta only in ESM RBD majority Delta cluster (0 seq(s)):
# set()
# Ground truth Delta only in ESM majority Delta cluster (2 seq(s):
# {'EPI_ISL_3428368', 'EPI_ISL_3428334'}
# Ground truth Delta only in MSA majority Delta cluster ((3 seq(s)):
# {'EPI_ISL_9021893', 'EPI_ISL_8136309', 'EPI_ISL_8289545'}

# %%
esm_rbd_omicron_df = esm_rbd_df[esm_rbd_df["Variant"] == "Omicron"]
esm_omicron_df = esm_df[esm_df["Variant"] == "Omicron"]
msa_omicron_df = msa_df[msa_df["Variant"] == "Omicron"]

# Convert columns to sets
set1 = set(esm_rbd_omicron_df["Seq ID"])
set2 = set(esm_omicron_df["Seq ID"])
set3 = set(msa_omicron_df["Seq ID"])

# Find differences
only_in_set1 = set1 - set2 - set3
only_in_set2 = set2 - set1 - set3
only_in_set3 = set3 - set1 - set2

print(f"Ground truth Omicron only in ESM RBD majority Delta cluster ({len(only_in_set1)} seq(s)):\n{only_in_set1}")
print(f"Ground truth Omicron only in ESM majority Delta cluster ({len(only_in_set2)} seq(s):\n{only_in_set2}")
print(f"Ground truth Omicron only in MSA majority Delta cluster (({len(only_in_set3)} seq(s)):\n{only_in_set3}")

plot_venn3([set1, set2, set3], "Omicron", "Delta", colors = ["#4A2C22FF", "tab:orange", "#F1CFA2FF"])
# Out:
# Ground truth Omicron only in ESM RBD majority Delta cluster (3 seq(s)):
# {'EPI_ISL_9221341', 'EPI_ISL_13113891', 'EPI_ISL_13113895'}
# Ground truth Omicron only in ESM majority Delta cluster (15 seq(s):
# {'EPI_ISL_16282525', 'EPI_ISL_15866869', 'EPI_ISL_16914554', 'EPI_ISL_15116352', 'EPI_ISL_10066002', 'EPI_ISL_14217015', 'EPI_ISL_9227490', 'EPI_ISL_9366647', 'EPI_ISL_14217016', 'EPI_ISL_13564370', 'EPI_ISL_16018900', 'EPI_ISL_8746647', 'EPI_ISL_16237804', 'EPI_ISL_9227748', 'EPI_ISL_16237895'}
# Ground truth Omicron only in MSA majority Delta cluster ((38 seq(s)):
# {'EPI_ISL_10025590', 'EPI_ISL_10240861', 'EPI_ISL_10103942', 'EPI_ISL_9355889', 'EPI_ISL_10075364', 'EPI_ISL_9221395', 'EPI_ISL_9728278', 'EPI_ISL_10746607', 'EPI_ISL_8605053', 'EPI_ISL_8426158', 'EPI_ISL_8748482', 'EPI_ISL_10025588', 'EPI_ISL_16674995', 'EPI_ISL_13140935', 'EPI_ISL_8501964', 'EPI_ISL_9120297', 'EPI_ISL_9103130', 'EPI_ISL_8632979', 'EPI_ISL_9635053', 'EPI_ISL_8970112', 'EPI_ISL_10072789', 'EPI_ISL_8801343', 'EPI_ISL_8719566', 'EPI_ISL_8551354', 'EPI_ISL_8082633', 'EPI_ISL_9259673', 'EPI_ISL_8481755', 'EPI_ISL_9204848', 'EPI_ISL_10016721', 'EPI_ISL_7624219', 'EPI_ISL_10025573', 'EPI_ISL_9527330', 'EPI_ISL_8066155', 'EPI_ISL_9902713', 'EPI_ISL_9432713', 'EPI_ISL_9417772', 'EPI_ISL_9199857', 'EPI_ISL_11859680'}

# %% [markdown]
# ---
# ### Omicron (Cluster 1)

# %%
import pandas as pd

# ESM-RBD Embedded
seed = 0
perplexity = 750
csv_file = f"rbd_ado/RBD.ADO.from-esm-mlm.CLS-embedded.sampled_seed0.tSNE-perplexity750.cluster1.csv"
esm_rbd_df = pd.read_csv(csv_file)
print(esm_rbd_df["Variant"].value_counts())

# ESM Embedded
seed = 0
perplexity = 1000
csv_file = f"rbd_ado/RBD.ADO.CLS-embedded.sampled_seed{seed}.tSNE-perplexity{perplexity}.cluster1.csv"
esm_df = pd.read_csv(csv_file)
print(esm_df["Variant"].value_counts())

# MSA + One-Hot Embedded
seed = 0
perplexity = 1000
csv_file = f"rbd_ado_msa/RBD.ADO.MSA.tSNE-perplexity{perplexity}.cluster1.csv"
msa_df = pd.read_csv(csv_file)
print(msa_df["Variant"].value_counts())
# Out:
# Variant
# Omicron    21787
# Delta         24
# Alpha         22
# Name: count, dtype: int64
# Variant
# Omicron    21691
# Delta          6
# Name: count, dtype: int64
# Variant
# Omicron    18152
# Name: count, dtype: int64

# %%
esm_rbd_alpha_df = esm_rbd_df[esm_rbd_df["Variant"] == "Alpha"]
esm_alpha_df = esm_df[esm_df["Variant"] == "Alpha"]
msa_alpha_df = msa_df[msa_df["Variant"] == "Alpha"]

# Convert columns to sets
set1 = set(esm_rbd_alpha_df["Seq ID"])
set2 = set(esm_alpha_df["Seq ID"])
set3 = set(msa_alpha_df["Seq ID"])

# Find differences
only_in_set1 = set1 - set2 - set3
only_in_set2 = set2 - set1 - set3
only_in_set3 = set3 - set1 - set2

print(f"Ground truth Alpha only in ESM RBD majority Omicron cluster ({len(only_in_set1)} seq(s)):\n{only_in_set1}")
print(f"Ground truth Alpha only in ESM majority Omicron cluster ({len(only_in_set2)} seq(s)):\n{only_in_set2}")
print(f"Ground truth Alpha only in MSA majority Omicron cluster ({len(only_in_set3)} seq(s)):\n{only_in_set3}")

plot_venn3([set1, set2, set3], "Alpha", "Omicron", colors = ["#244422FF", "tab:green", "#C8E6C9FF"])
# Out:
# Ground truth Alpha only in ESM RBD majority Omicron cluster (22 seq(s)):
# {'EPI_ISL_1565101', 'EPI_ISL_1927953', 'EPI_ISL_2724948', 'EPI_ISL_2099423', 'EPI_ISL_1907018', 'EPI_ISL_1382776', 'EPI_ISL_1801833', 'EPI_ISL_2182427', 'EPI_ISL_2185528', 'EPI_ISL_1527171', 'EPI_ISL_1232406', 'EPI_ISL_2422460', 'EPI_ISL_1556594', 'EPI_ISL_2535295', 'EPI_ISL_2250646', 'EPI_ISL_3133909', 'EPI_ISL_2382302', 'EPI_ISL_1756127', 'EPI_ISL_2124526', 'EPI_ISL_3130525', 'EPI_ISL_3769179', 'EPI_ISL_2151694'}
# Ground truth Alpha only in ESM majority Omicron cluster (0 seq(s)):
# set()
# Ground truth Alpha only in MSA majority Omicron cluster (0 seq(s)):
# set()

# %%
esm_rbd_delta_df = esm_rbd_df[esm_rbd_df["Variant"] == "Delta"]
esm_delta_df = esm_df[esm_df["Variant"] == "Delta"]
msa_delta_df = msa_df[msa_df["Variant"] == "Delta"]

# Convert columns to sets
set1 = set(esm_rbd_delta_df["Seq ID"])
set2 = set(esm_delta_df["Seq ID"])
set3 = set(msa_delta_df["Seq ID"])

# Find differences
only_in_set1 = set1 - set2 - set3
only_in_set2 = set2 - set1 - set3
only_in_set3 = set3 - set1 - set2

print(f"Ground truth Delta only in ESM RBD majority Omicron cluster ({len(only_in_set1)} seq(s)):\n{only_in_set1}")
print(f"Ground truth Delta only in ESM majority Omicron cluster ({len(only_in_set2)} seq(s):\n{only_in_set2}")
print(f"Ground truth Delta only in MSA majority Omicron cluster (({len(only_in_set3)} seq(s)):\n{only_in_set3}")

plot_venn3([set1, set2, set3], "Delta", "Omicron", colors = ["#244422FF", "tab:green", "#C8E6C9FF"])
# Out:
# Ground truth Delta only in ESM RBD majority Omicron cluster (22 seq(s)):
# {'EPI_ISL_3516777', 'EPI_ISL_4550097', 'EPI_ISL_3392894', 'EPI_ISL_8136309', 'EPI_ISL_6958671', 'EPI_ISL_8185267', 'EPI_ISL_4461329', 'EPI_ISL_6704463', 'EPI_ISL_8248291', 'EPI_ISL_3923763', 'EPI_ISL_3070867', 'EPI_ISL_8314889', 'EPI_ISL_8610358', 'EPI_ISL_9216909', 'EPI_ISL_3020283', 'EPI_ISL_9932873', 'EPI_ISL_3045407', 'EPI_ISL_8038089', 'EPI_ISL_4748063', 'EPI_ISL_8187047', 'EPI_ISL_4950220', 'EPI_ISL_7051443'}
# Ground truth Delta only in ESM majority Omicron cluster (4 seq(s):
# {'EPI_ISL_8310980', 'EPI_ISL_11575458', 'EPI_ISL_11814003', 'EPI_ISL_11575478'}
# Ground truth Delta only in MSA majority Omicron cluster ((0 seq(s)):
# set()

# %%
esm_rbd_omicron_df = esm_rbd_df[esm_rbd_df["Variant"] == "Omicron"]
esm_omicron_df = esm_df[esm_df["Variant"] == "Omicron"]
msa_omicron_df = msa_df[msa_df["Variant"] == "Omicron"]

# Convert columns to sets
set1 = set(esm_rbd_omicron_df["Seq ID"])
set2 = set(esm_omicron_df["Seq ID"])
set3 = set(msa_omicron_df["Seq ID"])

# Find differences
only_in_set1 = set1 - set2 - set3
only_in_set2 = set2 - set1 - set3
only_in_set3 = set3 - set1 - set2

print(f"Ground truth Omicron only in ESM RBD majority Omicron cluster ({len(only_in_set1)} seq(s)):\n{only_in_set1}")
print(f"Ground truth Omicron only in ESM majority Omicron cluster ({len(only_in_set2)} seq(s):\n{only_in_set2}")
print(f"Ground truth Omicron only in MSA majority Omicron cluster (({len(only_in_set3)} seq(s)):\n{only_in_set3}")

plot_venn3([set1, set2, set3], "Omicron", "Omicron", colors = ["#244422FF", "tab:green", "#C8E6C9FF"])
# Out:
# Ground truth Omicron only in ESM RBD majority Omicron cluster (120 seq(s)):
# {'EPI_ISL_15783310', 'EPI_ISL_16023273', 'EPI_ISL_9074364', 'EPI_ISL_9902091', 'EPI_ISL_9412067', 'EPI_ISL_14973240', 'EPI_ISL_15870588', 'EPI_ISL_14583230', 'EPI_ISL_9630463', 'EPI_ISL_13804580', 'EPI_ISL_8606298', 'EPI_ISL_14973137', 'EPI_ISL_14007566', 'EPI_ISL_13900024', 'EPI_ISL_10066059', 'EPI_ISL_9366647', 'EPI_ISL_16674995', 'EPI_ISL_14854983', 'EPI_ISL_15862107', 'EPI_ISL_15881786', 'EPI_ISL_14869684', 'EPI_ISL_16252782', 'EPI_ISL_13167239', 'EPI_ISL_8335317', 'EPI_ISL_14971078', 'EPI_ISL_16134967', 'EPI_ISL_9366739', 'EPI_ISL_9877928', 'EPI_ISL_15356528', 'EPI_ISL_14854936', 'EPI_ISL_13492865', 'EPI_ISL_14583189', 'EPI_ISL_17104142', 'EPI_ISL_8606230', 'EPI_ISL_13660646', 'EPI_ISL_14971441', 'EPI_ISL_8210402', 'EPI_ISL_14088514', 'EPI_ISL_15935974', 'EPI_ISL_15248356', 'EPI_ISL_11015499', 'EPI_ISL_14973160', 'EPI_ISL_13845329', 'EPI_ISL_8606215', 'EPI_ISL_16134963', 'EPI_ISL_17432667', 'EPI_ISL_13845327', 'EPI_ISL_13901546', 'EPI_ISL_16862469', 'EPI_ISL_16643153', 'EPI_ISL_11144326', 'EPI_ISL_14582996', 'EPI_ISL_15250603', 'EPI_ISL_13804596', 'EPI_ISL_15935987', 'EPI_ISL_14973257', 'EPI_ISL_15782540', 'EPI_ISL_17239005', 'EPI_ISL_15242942', 'EPI_ISL_16066660', 'EPI_ISL_11145319', 'EPI_ISL_8620480', 'EPI_ISL_16400579', 'EPI_ISL_16401035', 'EPI_ISL_15250201', 'EPI_ISL_10069065', 'EPI_ISL_8335232', 'EPI_ISL_16400535', 'EPI_ISL_14007463', 'EPI_ISL_15805765', 'EPI_ISL_17001754', 'EPI_ISL_14674128', 'EPI_ISL_15782561', 'EPI_ISL_15626959', 'EPI_ISL_10316776', 'EPI_ISL_15936032', 'EPI_ISL_8800935', 'EPI_ISL_8843404', 'EPI_ISL_17508217', 'EPI_ISL_16862489', 'EPI_ISL_15248351', 'EPI_ISL_14245305', 'EPI_ISL_13762621', 'EPI_ISL_17508178', 'EPI_ISL_14082932', 'EPI_ISL_13762535', 'EPI_ISL_13660603', 'EPI_ISL_16495455', 'EPI_ISL_14971484', 'EPI_ISL_13900026', 'EPI_ISL_8502142', 'EPI_ISL_14582392', 'EPI_ISL_13845316', 'EPI_ISL_15248342', 'EPI_ISL_14971461', 'EPI_ISL_14674275', 'EPI_ISL_15317251', 'EPI_ISL_17068290', 'EPI_ISL_15936028', 'EPI_ISL_14582967', 'EPI_ISL_15244437', 'EPI_ISL_14357040', 'EPI_ISL_16643118', 'EPI_ISL_12559510', 'EPI_ISL_8801343', 'EPI_ISL_16663378', 'EPI_ISL_15356525', 'EPI_ISL_14970997', 'EPI_ISL_8416673', 'EPI_ISL_8259454', 'EPI_ISL_14973258', 'EPI_ISL_10065623', 'EPI_ISL_14583031', 'EPI_ISL_16643991', 'EPI_ISL_14662219', 'EPI_ISL_10066048', 'EPI_ISL_15356537', 'EPI_ISL_11478969', 'EPI_ISL_17104067', 'EPI_ISL_15870477'}
# Ground truth Omicron only in ESM majority Omicron cluster (38 seq(s):
# {'EPI_ISL_11084124', 'EPI_ISL_11236273', 'EPI_ISL_11931066', 'EPI_ISL_8513971', 'EPI_ISL_12704498', 'EPI_ISL_8518693', 'EPI_ISL_9418351', 'EPI_ISL_13113905', 'EPI_ISL_14561381', 'EPI_ISL_9582395', 'EPI_ISL_9202411', 'EPI_ISL_9417029', 'EPI_ISL_8284507', 'EPI_ISL_8336438', 'EPI_ISL_10088223', 'EPI_ISL_9221341', 'EPI_ISL_9631959', 'EPI_ISL_8336454', 'EPI_ISL_11948879', 'EPI_ISL_14721894', 'EPI_ISL_8815828', 'EPI_ISL_8336441', 'EPI_ISL_13762578', 'EPI_ISL_12749913', 'EPI_ISL_14952220', 'EPI_ISL_10138509', 'EPI_ISL_9862288', 'EPI_ISL_11344916', 'EPI_ISL_15032659', 'EPI_ISL_14674182', 'EPI_ISL_15582076', 'EPI_ISL_10114898', 'EPI_ISL_12272394', 'EPI_ISL_9202992', 'EPI_ISL_8657418', 'EPI_ISL_11630165', 'EPI_ISL_13073691', 'EPI_ISL_9512430'}
# Ground truth Omicron only in MSA majority Omicron cluster ((9 seq(s)):
# {'EPI_ISL_17104058', 'EPI_ISL_12282751', 'EPI_ISL_13409761', 'EPI_ISL_12587166', 'EPI_ISL_15881617', 'EPI_ISL_14217012', 'EPI_ISL_12426922', 'EPI_ISL_12587202', 'EPI_ISL_11207527'}
